# %%
-23%10
# Out:
# 7

# %%
3%1.4
# Out:
# 0.20000000000000018

# %% [markdown]
# 19%-7

# %%
19%-7
# Out:
# -2

# %%
7.5/2
# Out:
# 3.75

# %%
7.5//2
# Out:
# 3.0

# %%
7.5%2
# Out:
# 1.5

# %%
77.9%5
# Out:
# 2.9000000000000057

# %%
2+3*4*4
# Out:
# 50

# %%
2**3
# Out:
# 8

# %%
2*3**3
# Out:
# 54

# %%
(3**3)//2
# Out:
# 13

# %%
2**12
# Out:
# 4096

# %%
2**3**2
# Out:
# 512

# %%
10-9+2**(16/4)//3
# Out:
# 6.0

# %%
2**-2**-2
# Out:
# 0.8408964152537145

# %% [markdown]
# 0.25**-2

# %%
0.25**-2
# Out:
# 16.0

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
2**1000
# Out:
# 

# %%
2**10000
# Out:
# ...

# %%
2**10000
# Out:
# ...
